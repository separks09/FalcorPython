# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
import requests
import json
from pprint import pprint

# %%
api_key = "AIzaSyA0szTwFB8VCtfeofMe-2458Dp2kErybqs"
url = "https://maps.googleapis.com/maps/api/geocode/json?"
csv = "Bigfoot.csv"
Bigfootraw= pd.read_csv(csv)
Bigfootraw.head()
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
#
#               timestamp  latitude  longitude
# 0  2000-06-16T12:00:00Z   61.5000  -142.9000
# 1  1995-05-15T12:00:00Z   55.1872  -132.7982
# 2  2004-02-09T12:00:00Z   55.2035  -132.8202
# 3  2004-06-18T12:00:00Z   62.9375  -141.5667
# 4  2004-02-15T12:00:00Z   61.0595  -149.7853

# %%
Bigfootraw1=Bigfootraw.dropna
Bigfootraw1
# Out:
# <bound method DataFrame.dropna of       number                                              title  \
# 0        637  Report 637: Campers' encounter just after dark...
# 1       2917  Report 2917: Family observes large biped from car
# 2       7963  Report 7963: Sasquatch walks past window of ho...
# 3       9317  Report 9317: Driver on Alcan Highway has noon,...
# 4      13038  Report 13038: Snowmobiler has encounter in dee...
# 5      23666  Report 23666: Passenger on the Alcan Highway s...
# 6      26604  Report 26604: Daytime sighting of reddish-colo...
# 7        179  Report 179: Man and witnesses have two seperat...
# 8        245  Report 245: Two outdoorsman fishing, loud voca...
# 9        416  Report 416: A resident's early evening sightin...
# 10       435  Report 435: Daylight sighting by husband and w...
# 11       451       Report 451: Young man has sighting near home
# 12       577  Report 577: Man has repeated visits at family ...
# ...

# %%
city=[]
state=[]
country =[]
lat=[]
lon=[]

for y in range(50):
    try:
        lats= Bigfootraw.iloc[y]["latitude"]
        lat.append(lats)
        long= Bigfootraw.iloc[y]["longitude"]
        lon.append(long)
        apicall=f"https://maps.googleapis.com/maps/api/geocode/json?latlng="+str(lats)+","+str(long)+"&"+api_key
        response=requests.get(apicall)
        data=response.json()
        city.append(data['results'][0]['address_components'][1]['long_name'])
        state.append(data['results'][0]['address_components'][3]['short_name'])
        country.append(data['results'][0]['address_components'][4]['short_name'])
    except:
        continue
    
city
# Out:
# ['Chitina',
#  'Craig',
#  'Hydaburg',
#  'Alaska 2',
#  'Bettijean Street',
#  'Northway',
#  'Auburn Drive',
#  'Old Seale Highway',
#  'Brookwood',
#  'Old Limestone Road',
#  'Baker Road',
#  'Chapman Hollow Road',
#  'Jasper Road',
#  'Wagarville',
#  'Westview Lane',
#  'Tuskegee',
#  'Ashley Drive',
#  'West Tuskeena Street',
#  'Alabama 21',
#  'Hammock Bridge',
#  'Nursery Road',
#  'County Road 205',
#  'North Brindlee Mountain Parkway']

# %%
A_Class_Sightingsdf=Bigfootraw.loc[Bigfootraw["classification"]=="Class A"]
A_Class_Sightingsdf
# Out:
#       number                                              title  \
# 0        637  Report 637: Campers' encounter just after dark...
# 1       2917  Report 2917: Family observes large biped from car
# 2       7963  Report 7963: Sasquatch walks past window of ho...
# 3       9317  Report 9317: Driver on Alcan Highway has noon,...
# 4      13038  Report 13038: Snowmobiler has encounter in dee...
# 5      23666  Report 23666: Passenger on the Alcan Highway s...
# 6      26604  Report 26604: Daytime sighting of reddish-colo...
# 7        179  Report 179: Man and witnesses have two seperat...
# 8        245  Report 245: Two outdoorsman fishing, loud voca...
# 9        416  Report 416: A resident's early evening sightin...
# 10       435  Report 435: Daylight sighting by husband and w...
# 11       451       Report 451: Young man has sighting near home
# 12       577  Report 577: Man has repeated visits at family ...
# 13       799  Report 799: Person fishing recounts story of h...
# ...

# %%
B_Class_Sightingsdf=Bigfootraw.loc[Bigfootraw["classification"]=="Class B"]
B_Class_Sightingsdf
# Out:
#       number                                              title  \
# 1895    6486  Report 6486: Special Forces team follows biped...
# 1896    8792  Report 8792: Four nocturnal hikers get pelted ...
# 1897    8797  Report 8797: Two boys find footprints on Harri...
# 1898   11616  Report 11616: Fishermen find footprints east o...
# 1899   25442  Report 25442: Hunter describes powerful wood k...
# 1900     273  Report 273: Husband and wife hear scream while...
# 1901    1419  Report 1419: Large footprint found in a sandy ...
# 1902    1783  Report 1783: Night hunters hear strange scream...
# 1903    8635  Report 8635: Possible repeat approaches to a r...
# 1904    8921  Report 8921: Possible daylight sighting near f...
# 1905   10501  Report 10501: Hikers find footprints near Pell...
# 1906   15473  Report 15473: Possible stalking on mountain ou...
# 1907   15597  Report 15597: Possible vocalizations reported ...
# 1908   17035  Report 17035: Wood knocks heard by hunter outs...
# ...

# %%
C_Class_Sightingsdf=Bigfootraw.loc[Bigfootraw["classification"]=="Class C"]
C_Class_Sightingsdf
# Out:
#       number                                              title  \
# 3791     483  Report 483: Multiple witnesses describe multip...
# 3792    1830  Report 1830: Two separate sighting reports of ...
# 3793    4096  Report 4096: Sighting by truck driver near Fel...
# 3794    2779  Report 2779: A Local Writer Discusses Her Expe...
# 3795   25381  Report 25381: Large bipedal figure seen leapin...
# 3796     444  Report 444: Family sightings over 100 years in...
# 3797    2806  Report 2806: The "Big Muddy Monster" flap of M...
# 3798    3467  Report 3467: Witnesses describe 'huge' black c...
# 3799    3471  Report 3471: Beige upright creature seen at a ...
# 3800    3472  Report 3472: Series of three incidents describ...
# 3801    1208  Report 1208: Vocalizing, smelly animal circles...
# 3802    1649  Report 1649: Witnesses hear two powerful vocal...
# 3803    1700  Report 1700: Witnesses hear unusual screams wh...
# 3804    4156  Report 4156: Loud, high-pitched, close-range s...
# ...
