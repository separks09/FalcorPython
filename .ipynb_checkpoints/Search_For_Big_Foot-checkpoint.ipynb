# %%
# Dependencies
import pandas as pd
import numpy as np
import tweepy
import json
from pprint import pprint

from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Define search Term
query = "bigfoot"

# Search for all tweets
public_tweets = api.search(query, rpp=100, show_user=True)

# View Search Object
print(public_tweets)
# Out:
# {'statuses': [{'created_at': 'Sat Apr 07 03:16:10 +0000 2018', 'id': 982456973953323009, 'id_str': '982456973953323009', 'text': 'RT @WeirdCrimeFacts: The 1967 Bigfoot footage stabilized. https://t.co/6LhxXsNPDA', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'WeirdCrimeFacts', 'name': 'Crime And Punishment', 'id': 1014760268, 'id_str': '1014760268', 'indices': [3, 19]}], 'urls': [], 'media': [{'id': 685872059323383809, 'id_str': '685872059323383809', 'indices': [58, 81], 'media_url': 'http://pbs.twimg.com/tweet_video_thumb/CYS1AQlWAAEaRv7.png', 'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/CYS1AQlWAAEaRv7.png', 'url': 'https://t.co/6LhxXsNPDA', 'display_url': 'pic.twitter.com/6LhxXsNPDA', 'expanded_url': 'https://twitter.com/NotExplained/status/685872078164226048/photo/1', 'type': 'photo', 'sizes': {'small': {'w': 460, 'h': 324, 'resize': 'fit'}, 'large': {'w': 460, 'h': 324, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 460, 'h': 324, 'resize': 'fit'}}, 'source_status_id': 685872078164226048, 'source_status_id_str': '685872078164226048', 'source_user_id': 1681324362, 'source_user_id_str': '1681324362'}]}, 'extended_entities': {'media': [{'id': 685872059323383809, 'id_str': '685872059323383809', 'indices': [58, 81], 'media_url': 'http://pbs.twimg.com/tweet_video_thumb/CYS1AQlWAAEaRv7.png', 'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/CYS1AQlWAAEaRv7.png', 'url': 'https://t.co/6LhxXsNPDA', 'display_url': 'pic.twitter.com/6LhxXsNPDA', 'expanded_url': 'https://twitter.com/NotExplained/status/685872078164226048/photo/1', 'type': 'animated_gif', 'sizes': {'small': {'w': 460, 'h': 324, 'resize': 'fit'}, 'large': {'w': 460, 'h': 324, 'resize': 'fit'}, 'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 460, 'h': 324, 'resize': 'fit'}}, 'source_status_id': 685872078164226048, 'source_status_id_str': '685872078164226048', 'source_user_id': 1681324362, 'source_user_id_str': '1681324362', 'video_info': {'aspect_ratio': [115, 81], 'variants': [{'bitrate': 0, 'content_type': 'video/mp4', 'url': 'https://video.twimg.com/tweet_video/CYS1AQlWAAEaRv7.mp4'}]}}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 4760561432, 'id_str': '4760561432', 'name': 'Your Kitsune/Nekos', 'screen_name': 'Yui_and_Kichigo', 'location': 'Everywhere and Nowhere', 'description': '12+ characters. Bi #MVRP #AnyRP\nAccount b-day on January 15th\nNone of the art is mine unless said so.\n(N)SFW\nYuki is taken by @DragonKing028', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1560, 'friends_count': 2418, 'listed_count': 5, 'created_at': 'Fri Jan 15 01:06:39 +0000 2016', 'favourites_count': 38720, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 29692, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/975200251652001792/54-s_dLI_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/975200251652001792/54-s_dLI_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4760561432/1511299980', 'profile_link_color': '000000', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, ...

# %%
# Search for all tweets
public_tweets = api.search(query, rpp=100, show_user=True)

# Loop through all tweets
for tweet in public_tweets["statuses"]:
    
    print(tweet["text"])
# Out:
# RT @WeirdCrimeFacts: The 1967 Bigfoot footage stabilized. https://t.co/6LhxXsNPDA
# RT @WeirdCrimeFacts: The 1967 Bigfoot footage stabilized. https://t.co/6LhxXsNPDA
# https://t.co/5hVLkZT86t - Bigfoot Team Gets Followed https://t.co/G8RJQO4D2k
# In addition to hunting the last living Bigfoot for game and initiating the Irish Potato Famine, Richard C. Meyer wi… https://t.co/woqRVHwsVA
# RT @WeirdCrimeFacts: The 1967 Bigfoot footage stabilized. https://t.co/6LhxXsNPDA
# RT @smbeckley: Bigfoot? I fucked her.
# RT @what_tha_pantha: Me, Victoria, Mic, and Kenzie have concluded that Bigfoot is not a big ass hairy man/Sasquatch, but he’s a just a big…
# RT @WeirdCrimeFacts: The 1967 Bigfoot footage stabilized. https://t.co/6LhxXsNPDA
# Dans ma fanfiction doctor who, Bigfoot a pris de la drogue.
# Now my human neighbor is on the back porch with a spotlight saying, “What was that?!  Did you hear it?!”  Female sa… https://t.co/lZOpsKv0hb
# @michaelbay I would love to see you make a bigfoot movie!
# RT @smbeckley: Bigfoot? I fucked her.
# RT @jamisonrocket: @WeirdCrimeFacts Bigfoot walks like his mom sent him to his room with no dinner #Believe
# RT @WeirdCrimeFacts: The 1967 Bigfoot footage stabilized. https://t.co/6LhxXsNPDA
# RT @WeirdCrimeFacts: The 1967 Bigfoot footage stabilized. https://t.co/6LhxXsNPDA
