# %%
# Dependencies
import pandas as pd
import numpy as np
import tweepy
import json
from pprint import pprint

from config import consumer_key, consumer_secret, access_token, access_token_secret

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Define search Term
query = "bigfoot"

# Search for all tweets
public_tweets = api.search(query, lang="en", rpp='limit', show_user=True)

# View Search Object
print(public_tweets)
# Out:
# {'statuses': [{'created_at': 'Sat Apr 07 14:36:25 +0000 2018', 'id': 982628163627945987, 'id_str': '982628163627945987', 'text': 'RT @JFRocks: Have you heard my latest, a #surf #guitar rocker called ‘Bogus Bigfoot’ on #SoundCloud? #np https://t.co/DpaAuYOzHv', 'truncated': False, 'entities': {'hashtags': [{'text': 'surf', 'indices': [41, 46]}, {'text': 'guitar', 'indices': [47, 54]}, {'text': 'SoundCloud', 'indices': [88, 99]}, {'text': 'np', 'indices': [101, 104]}], 'symbols': [], 'user_mentions': [{'screen_name': 'JFRocks', 'name': 'Jeff Fiorentino', 'id': 73185350, 'id_str': '73185350', 'indices': [3, 11]}], 'urls': [{'url': 'https://t.co/DpaAuYOzHv', 'expanded_url': 'https://soundcloud.com/jeff-fiorentino-jfrocks/bogus-bigfoot?utm_source=soundcloud&utm_campaign=share&utm_medium=twitter', 'display_url': 'soundcloud.com/jeff-fiorentin…', 'indices': [105, 128]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3401207614, 'id_str': '3401207614', 'name': 'Bellalolz1966', 'screen_name': 'Lolz1975Tilly', 'location': 'UK ', 'description': 'Mother love of animals horror movies and supernatural anything creepy lover of music and nature', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2151, 'friends_count': 741, 'listed_count': 11, 'created_at': 'Mon Aug 03 11:01:42 +0000 2015', 'favourites_count': 227125, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 39419, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/628159600789995520/QeB_9hj4_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/628159600789995520/QeB_9hj4_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3401207614/1438599845', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Sat Apr 07 14:34:05 +0000 2018', 'id': 982627576697864192, 'id_str': '982627576697864192', 'text': 'Have you heard my latest, a #surf #guitar rocker called ‘Bogus Bigfoot’ on #SoundCloud? #np https://t.co/DpaAuYOzHv', 'truncated': False, 'entities': {'hashtags': [{'text': 'surf', 'indices': [28, 33]}, {'text': 'guitar', 'indices': [34, 41]}, {'text': 'SoundCloud', 'indices': [75, 86]}, {'text': 'np', 'indices': [88, 91]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/DpaAuYOzHv', 'expanded_url': 'https://soundcloud.com/jeff-fiorentino-jfrocks/bogus-bigfoot?utm_source=soundcloud&utm_campaign=share&utm_medium=twitter', 'display_url': 'soundcloud.com/jeff-fiorentin…', 'indices': [92, 115]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 73185350, 'id_str': '73185350', 'name': 'Jeff Fiorentino', 'screen_na ...

# %%
# Search for all tweets
public_tweets = api.search(query, lang="en", rpp='limit', show_user=True)

# Loop through all tweets
for tweet in public_tweets["statuses"]:
    
    print(tweet["text"])
# Out:
# RT @JFRocks: Have you heard my latest, a #surf #guitar rocker called ‘Bogus Bigfoot’ on #SoundCloud? #np https://t.co/DpaAuYOzHv
# RT @one_bad_cat1: 😎 ________Bigfoot!______________😂😹😀😁😸🌐⤵😛😋 https://t.co/N1GuZ1wSpe
# RT @ThoseUSAGirls: @NYCmixedbreed @Stefeenew @Judy_Cockerton @AMlzner @DeborahGeeMusic @mikma @DUKETHEMAN1 @Kimberlyjesicka @The_DailyWA @W…
# RT @Night_Wolf_1: Have you heard ‘Bogus Bigfoot’ by @JFRocks on #SoundCloud? #np https://t.co/lLezkqm2iR
# RT @BehindTheBrains: The mighty mighty #hollywood #guitarist .@JFRocks taking me on a #surfing safari today with his latest release "Bogus…
# RT @JFRocks: Have you heard my latest, a #surf #guitar rocker called ‘Bogus Bigfoot’ on #SoundCloud? #np https://t.co/DpaAuYOzHv
# RT @JFRocks: Have you heard my latest, a #surf #guitar rocker called ‘Bogus Bigfoot’ on #SoundCloud? #np https://t.co/DpaAuYOzHv
# RT @BrownDogBlanket: Maybe nobody has ever seen Bigfoot because he’s self conscious.
# Have you heard my latest, a #surf #guitar rocker called ‘Bogus Bigfoot’ on #SoundCloud? #np https://t.co/DpaAuYOzHv
# #99cents #BIGFOOT ISLAND
# 👣 https://t.co/b6YcJeFq4R
# 👣 https://t.co/Tl1o2bGbB2
# 👣 https://t.co/W3JuRV5H7x
# https://t.co/UeMZZNxhcw
# RT @MisterLobo: Watch “Cinema Insomnia - Bigfoot Mysterious Monster” by @Channel_OSI74 on #Vimeo https://t.co/0QdJ0h8Z6X
# USA Explorers Found a Bigfoot Lair 2018 https://t.co/6z6wXpExzv via @YouTube
# @migsdelamusica @bigfoot_life @mvp1979jr You might be fine bro, the suede and mesh toe box isent going to be stretchy at all.
# RT @BalluGururaj: Freedom at its Peak in India to the BigShots  but more tragic is that millions of Mod Slaves in the name of Fans/Follower…
# @philefan4life @Jaide_Alicia @davidcoverdale Thundermother, Wayward Sons, Dirty Sweet, Tequila Mockingbyrd, Souls O… https://t.co/gaDpidISiI
