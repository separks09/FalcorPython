# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy

# %%
csv = "Bigfoot.csv"
Bigfootraw= pd.read_csv(csv)
Bigfootraw.head()
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
#
#               timestamp  latitude  longitude
# 0  2000-06-16T12:00:00Z   61.5000  -142.9000
# 1  1995-05-15T12:00:00Z   55.1872  -132.7982
# 2  2004-02-09T12:00:00Z   55.2035  -132.8202
# 3  2004-06-18T12:00:00Z   62.9375  -141.5667
# 4  2004-02-15T12:00:00Z   61.0595  -149.7853

# %%
A_Class_Sightingsdf=Bigfootraw.loc[Bigfootraw["classification"]=="Class A"]
A_Class_Sightingsdf.head()
# Out:
#    number                                              title classification  \
# 0     637  Report 637: Campers' encounter just after dark...        Class A
# 1    2917  Report 2917: Family observes large biped from car        Class A
# 2    7963  Report 7963: Sasquatch walks past window of ho...        Class A
# 3    9317  Report 9317: Driver on Alcan Highway has noon,...        Class A
# 4   13038  Report 13038: Snowmobiler has encounter in dee...        Class A
#
#               timestamp  latitude  longitude
# 0  2000-06-16T12:00:00Z   61.5000  -142.9000
# 1  1995-05-15T12:00:00Z   55.1872  -132.7982
# 2  2004-02-09T12:00:00Z   55.2035  -132.8202
# 3  2004-06-18T12:00:00Z   62.9375  -141.5667
# 4  2004-02-15T12:00:00Z   61.0595  -149.7853

# %%
B_Class_Sightingsdf=Bigfootraw.loc[Bigfootraw["classification"]=="Class B"]
B_Class_Sightingsdf.head()
# Out:
#       number                                              title  \
# 1895    6486  Report 6486: Special Forces team follows biped...
# 1896    8792  Report 8792: Four nocturnal hikers get pelted ...
# 1897    8797  Report 8797: Two boys find footprints on Harri...
# 1898   11616  Report 11616: Fishermen find footprints east o...
# 1899   25442  Report 25442: Hunter describes powerful wood k...
#
#      classification             timestamp  latitude  longitude
# 1895        Class B  1988-03-15T12:00:00Z  69.50000  -156.7500
# 1896        Class B  2003-12-12T12:00:00Z  61.09085  -149.7667
# 1897        Class B  2001-05-13T12:00:00Z  55.45550  -132.7333
# 1898        Class B  2004-07-20T12:00:00Z  57.75660  -155.9810
# 1899        Class B  2008-08-20T12:00:00Z  63.98869  -142.7691

# %%
C_Class_Sightingsdf=Bigfootraw.loc[Bigfootraw["classification"]=="Class C"]
C_Class_Sightingsdf.head()
# Out:
#       number                                              title  \
# 3791     483  Report 483: Multiple witnesses describe multip...
# 3792    1830  Report 1830: Two separate sighting reports of ...
# 3793    4096  Report 4096: Sighting by truck driver near Fel...
# 3794    2779  Report 2779: A Local Writer Discusses Her Expe...
# 3795   25381  Report 25381: Large bipedal figure seen leapin...
#
#      classification             timestamp  latitude  longitude
# 3791        Class C  1996-04-15T12:00:00Z  33.94175  -86.17965
# 3792        Class C  1975-08-25T12:00:00Z  34.12880  -86.68000
# 3793        Class C  1980-01-01T12:00:00Z  33.10750  -92.33472
# 3794        Class C  1981-02-15T12:00:00Z  32.71528 -117.15640
# 3795        Class C  2004-09-15T12:00:00Z  28.21492  -82.45240

# %%
city = citipy.nearest_city(latitude=Bigfootraw["latitude"],longitude=Bigfootraw["longitude"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-49fda48e1bab> in <module>()
# ----> 1 city = citipy.nearest_city(latitude=Bigfootraw["latitude"],longitude=Bigfootraw["longitude"])
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\citipy\citipy.py in nearest_city(latitude, longitude)
#      35
#      36 def nearest_city(latitude, longitude):
# ---> 37     nearest_city_coordinate = _world_cities_kdtree.search_nn((latitude, longitude, ))
#      38     return WORLD_CITIES_DICT[nearest_city_coordinate[0].data]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\kdtree.py in _wrapper(self, *args, **kwargs)
#     195                     dict(func_name=f.__name__, node=repr(self)))
#     196
# --> 197         return f(self, *args, **kwargs)
#     198
#     199     return _wrapper
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\kdtree.py in search_nn(self, point, dist)
#     490         """
#     491
# --> 492         return next(iter(self.search_knn(point, 1, dist)), None)
#     493
#     494
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\kdtree.py in search_knn(self, point, k, dist)
#     422         results = []
#     423
# --> 424         self._search_node(point, k, results, get_dist, itertools.count())
#     425
#     426         # We sort the final result by the distance in the tuple
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\kdtree.py in _search_node(self, point, k, results, get_dist, counter)
#     433             return
#     434
# --> 435         nodeDist = get_dist(self)
#     436
#     437         # Add current node to the priority queue if it closer than
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\kdtree.py in <lambda>(n)
#     416
#     417         if dist is None:
# --> 418             get_dist = lambda n: n.dist(point)
#     419         else:
#     420             get_dist = lambda n: dist(n.data, point)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\kdtree.py in dist(self, point)
#     394         """
#     395         r = range(self.dimensions)
# --> 396         return sum([self.axis_dist(point, i) for i in r])
#     397
#     398
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\kdtree.py in <listcomp>(.0)
#     394         """
#     395         r = range(self.dimensions)
# --> 396         return sum([self.axis_dist(point, i) for i in r])
#     397
#     398
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\kdtree.py in axis_dist(self, point, axis)
#     385         the current Node and the given point
#     386         """
# --> 387         return math.pow(self.data[axis] - point[axis], 2)
#     388
#     389
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\series.py in wrapper(self)
#     110             return converter(self.iloc[0])
#     111         raise TypeError("cannot convert the series to "
# --> 112                         "{0}".format(str(converter)))
#     113
#     114     return wrapper
#
# TypeError: cannot convert the series to <class 'float'>
